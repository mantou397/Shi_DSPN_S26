# %% [markdown]
# <a href="https://colab.research.google.com/github/RobJavVar/DataSciencePsychNeuro/blob/master/ExerciseSubmissions/10_mixed-effects-models.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exercise 10: Mixed effects

# %% [markdown]
# This homework assignment is designed to give you practice fitting and interpreting mixed effects models.
#
# We will be using the **LexicalData.csv** and **Items.csv** files from the *Homework/lexDat* folder in the class GitHub repository again.
#
# This data is a subset of the [English Lexicon Project database](https://elexicon.wustl.edu/). It provides the reaction times (in milliseconds) of many subjects as they are presented with letter strings and asked to decide, as quickly and as accurately as possible, whether the letter string is a word or not. The **Items.csv** provides characteristics of the words used, namely frequency (how common is this word?) and length (how many letters?). Unlike in the previous homework, there isn't any missing data in the **LexicalData.csv** file.
#
# *Data courtesy of Balota, D.A., Yap, M.J., Cortese, M.J., Hutchison, K.A., Kessler, B., Loftis, B., Neely, J.H., Nelson, D.L., Simpson, G.B., & Treiman, R. (2007). The English Lexicon Project. Behavior Research Methods, 39, 445-459.*

# %% [markdown]
# ---
# ## 1. Loading and formatting the data (1 point)
#
# Load in data from the **LexicalData.csv** and **Items.csv** files. As in the previous homeworks, remove the commas from the reaction times and convert them from strings to numbers. Use `left_join` to add word characteristics `Length` and `Log_Freq_Hal` from **Items** to **LexicalData**.
#
# *Note: the `Freq_HAL` variable in **Items.csv** has a similar formatting issue, using string values with commas. We're not going to worry about fixing this since we're only using `Log_Freq_HAL`, which is the natural log transformation of `Freq_HAL`, in this homework.*

# %%
library(dplyr)

# Load data
lexical_data <- read.csv("/Users/belinda/Desktop/85403/GitHub/DataSciencePsychNeuro/Exercise datasets/lexDat/LexicalData.csv")
items <- read.csv("/Users/belinda/Desktop/85403/GitHub/DataSciencePsychNeuro/Exercise datasets/lexDat/Items.csv")

# Remove commas from reaction times and convert to numeric
lexical_data$D_RT <- as.numeric(gsub(",", "", lexical_data$D_RT))

# Join word characteristics to lexical data
lexical_data <- left_join(lexical_data, items %>% select(Word, Length, Log_Freq_HAL), by = c("D_Word" = "Word"))

# Visualize
head (lexical_data)
# Out:
#   Sub_ID Trial Type D_RT D_Word      Outlier D_Zscore Length Log_Freq_HAL
# 1 157    1     1     710 browse      false   -0.437    6     8.856
# 2  67    1     1    1094 refrigerant false    0.825   11     4.644
# 3 120    1     1     587 gaining     false   -0.645    7     8.304
# 4  21    1     1     984 cheerless   false    0.025    9     2.639
# 5 236    1     1     577 pattered    false   -0.763    8     1.386
# 6 236    2     1     715 conjures    false   -0.364    8     5.268

# %% [markdown]
# ---
# ## 2. Model fitting (4 points)

# %% [markdown]
# First, fit a linear model with `Log_Freq_HAL` and `Length` as predictors, and `D_RT` as the output. Include an interaction term. Use `summary()` to look at the model output.

# %%
model <- lm(D_RT ~ Log_Freq_HAL * Length, data = lexical_data)
summary(model)
# Out:
# Call:
# lm(formula = D_RT ~ Log_Freq_HAL * Length, data = lexical_data)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -1118.01  -205.23   -86.95    90.77  3147.07
#
# Coefficients:
#                     Estimate Std. Error t value Pr(>|t|)
# (Intercept)         610.1903    14.6678  41.601  < 2e-16 ***
# Log_Freq_HAL         -6.0239     1.9678  -3.061  0.00221 **
# Length               47.7531     1.6368  29.175  < 2e-16 ***
# Log_Freq_HAL:Length  -2.9421     0.2348 -12.528  < 2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 359.1 on 62606 degrees of freedom
# Multiple R-squared:  0.09473,	Adjusted R-squared:  0.09469
# F-statistic:  2184 on 3 and 62606 DF,  p-value: < 2.2e-16

# %% [markdown]
# Now, install `lme4` using `install.packages()` and then load the library.

# %%
install.packages("lme4")
library(lme4)
# Out:
# The downloaded binary packages are in
# 	/var/folders/98/fcbf3bz156j770hhtccd780w0000gq/T//RtmpcosgRm/downloaded_packages

# %% [markdown]
# Now fit a mixed effects model that includes the same predictors as the linear model above, as well as random intercepts for `Sub_ID` (i.e., cases where subject ID shifts the RT mean). Use `summary()` to look at the model output.

# %%
model_mix <- lmer(D_RT ~ Log_Freq_HAL * Length + (1 | Sub_ID), data = lexical_data)
summary(model_mix)
# Out:
# Linear mixed model fit by REML ['lmerMod']
# Formula: D_RT ~ Log_Freq_HAL * Length + (1 | Sub_ID)
#    Data: lexical_data
#
# REML criterion at convergence: 888235.6
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -4.5058 -0.5472 -0.1568  0.3103 10.7381
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  Sub_ID   (Intercept) 46333    215.3
#  Residual             82978    288.1
# Number of obs: 62610, groups:  Sub_ID, 299
#
# Fixed effects:
#                     Estimate Std. Error t value
# (Intercept)         616.8445    17.1522  35.963
# Log_Freq_HAL         -7.4374     1.5830  -4.698
# Length               47.7477     1.3162  36.277
# Log_Freq_HAL:Length  -2.8778     0.1888 -15.239
#
# Correlation of Fixed Effects:
#             (Intr) Lg_F_HAL Length
# Log_Frq_HAL -0.645
# Length      -0.656  0.917
# Lg_Fr_HAL:L  0.582 -0.942   -0.923

# %% [markdown]
# ---
# ## 3. Model assessment (4 points)

# %% [markdown]
# Compare the three t-values for the fixed effects and the mixed effects models. How do they differ, and why?

# %% [markdown]
# > *Write your response here*
# >
# > The t-values for all three effects are larger in magnitude (absolute value) in the mixed effects model compared to the linear model. Maybe this is becasue the mixed effects model can account for the variability between subjects by including random intercepts for Sub_ID. So by partitioning out the between-subject variance, the residual error is potentially reduced. So this may lead to smaller standard errors for the fixed effecrts estimates and then larger magnitide in t-values. So mixed models may potentially give us more precise estimates of the fixed effects by properly modeling the structure of the data. Also, the signs (positive or negative) among the three t-values did not change for the mixed model. So this difference did not change the direction of the effects.

# %% [markdown]
# Use the Aikeke Information Criterion (AIC) to compare these two models. Which one is better?

# %%
AIC(model, model_mix)
# Out:
#           df AIC
# model     5  914436.4
# model_mix 6  888247.6

# %% [markdown]
# > *Write your response here*
# >
# > Here we can see that the mixed effects model has a lower AIC than the pure linear model. This would indicate that the mixed effects model provides a better fit to the data. This lower AIC would refflect both the improved fit from accounting for subject-level variability and that the additional random intercept parrameter is justified.

# %% [markdown]
# ---
# ##  4. Reflection (1 point)
#
# What other random effects could be controlled for in this data set?
#
# > *Write your response here*
# >
# > In addition to random intercepts for Sub_ID, we can consider including random intercepts for words (D_Word). This is because since different subjects may have inherently faster or slower reaction times, different words may be inherently taking longer or shorter time to recognize beyond what is captured by Length and Log_Freq_HAL. As an example, some words could reflect more abstract things like math, while others reflect more daily objects like apples. Then they may be inherently different to process.

# %% [markdown]
# **DUE:** 5pm EST, March 5, 2026

# %% [markdown]
# **IMPORTANT** Did you collaborate with anyone on this assignment? If so, list their names here.
# > *Someone's Name*
